# %%
import csv as csv
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from c_online_linear_regression import getData, summarize_by_makeyear

dfMasterCrashAgg, dfSales = getData()

# %%
#     df_agg = aggregate(df_final, ['MOD_YEAR', 'Make_ID', 'Model_ID','ACC_YEAR'])
x = {}
# x['Alfa Romeo']  = {'Make_ID':31}
# x['AM General']  = {'Make_ID':3}
# x['American Motors']  = {'Make_ID':1}
x['Audi']  = {'Make_ID':32}
# x['Austin/Austin Healey']  = {'Make_ID':33}
# x['Bluebird']  = {'Make_ID':90}
x['BMW']  = {'Make_ID':34}
# x['Brockway']  = {'Make_ID':80}
# x['BSA']  = {'Make_ID':70}
# x['Buick / Opel']  = {'Make_ID':18}
x['Cadillac']  = {'Make_ID':19}
x['Chevrolet']  = {'Make_ID':20}
# x['Chrysler']  = {'Make_ID':6}
# x['Coda']  = {'Make_ID':26}
# x['Daewoo']  = {'Make_ID':64}
# x['Daihatsu']  = {'Make_ID':60}
# x['Diamond Reo/Reo']  = {'Make_ID':81}
# x['Dodge']  = {'Make_ID':7}
# x['Ducati']  = {'Make_ID':71}
# x['Eagle']  = {'Make_ID':10}
# x['Eagle Coach']  = {'Make_ID':91}
# x['Fiat']  = {'Make_ID':36}
x['Ford']  = {'Make_ID':12}
# x['Freightliner']  = {'Make_ID':82}
# x['FWD']  = {'Make_ID':83}
# x['Gillig']  = {'Make_ID':92}
x['GMC']  = {'Make_ID':23}
# x['Grumman']  = {'Make_ID':25}
# x['Harley-Davidson']  = {'Make_ID':72}
x['Honda']  = {'Make_ID':37}
x['Hyundai']  = {'Make_ID':55}
# x['Imperial']  = {'Make_ID':8}
# x['Infiniti']  = {'Make_ID':58}
# x['International Harvester/Navistar']  = {'Make_ID':84}
# x['Isuzu']  = {'Make_ID':38}
# x['Iveco/Magirus']  = {'Make_ID':88}
# x['Jaguar']  = {'Make_ID':39}
x['Jeep / Kaiser-Jeep / Willys- Jeep']  = {'Make_ID':2}
# x['Kawasaki']  = {'Make_ID':73}
# x['Kenworth']  = {'Make_ID':85}
x['KIA']  = {'Make_ID':63}
# x['Lancia']  = {'Make_ID':40}
# x['Land Rover']  = {'Make_ID':62}
x['Lexus']  = {'Make_ID':59}
# x['Lincoln']  = {'Make_ID':13}
# x['Mack']  = {'Make_ID':86}
# x['Mazda']  = {'Make_ID':41}
# x['MCI']  = {'Make_ID':93}
x['Mercedes-Benz']  = {'Make_ID':42}
# x['Mercury']  = {'Make_ID':14}
# x['Merkur']  = {'Make_ID':56}
# x['MG']  = {'Make_ID':43}
# x['Mitsubishi']  = {'Make_ID':52}
# x['Moto-Guzzi']  = {'Make_ID':74}
x['Nissan/Datsun']  = {'Make_ID':35}
# x['Norton']  = {'Make_ID':75}
# x['Not Reported']  = {'Make_ID':97}
# x['Oldsmobile']  = {'Make_ID':21}
# x['Other Domestic Manufacturers']  = {'Make_ID':29}
# x['Other Import']  = {'Make_ID':69}
# x['Other Make']  = {'Make_ID':98}
# x['Peterbilt']  = {'Make_ID':87}
# x['Peugeot']  = {'Make_ID':44}
# x['Plymouth']  = {'Make_ID':9}
# x['Pontiac']  = {'Make_ID':22}
x['Porsche']  = {'Make_ID':45}
# x['Renault']  = {'Make_ID':46}
# x['Saab']  = {'Make_ID':47}
# x['Saturn']  = {'Make_ID':24}
# x['Scion']  = {'Make_ID':67}
# x['Smart']  = {'Make_ID':65}
# x['Sterling']  = {'Make_ID':61}
# x['Subaru']  = {'Make_ID':48}
# x['Suzuki']  = {'Make_ID':53}
# x['Thomas Built']  = {'Make_ID':94}
x['Toyota']  = {'Make_ID':49}
# x['Triumph']  = {'Make_ID':50}
# x['Unknown Make']  = {'Make_ID':99}
# x['Victory']  = {'Make_ID':77}
x['Volkswagen']  = {'Make_ID':30}
x['Volvo']  = {'Make_ID':51}
# x['White/Autocar White/GMC']  = {'Make_ID':89}
# x['Yamaha']  = {'Make_ID':76}
# x['Yugo']  = {'Make_ID':57}

# plt.rcParams['figure.figsize'] = [16, 8]


modelYrStart=2005
modelYrEnd  =2005

# summarize_by_makeyear( dfMasterCrashAgg, modelYrStart, modelYrEnd, makes_dict=x)
summarize_by_makeyear( dfMasterCrashAgg, modelYrStart, modelYrEnd, makes_dict=x, dfSales=dfSales
                     , showLinearRegress=True)
# Out:
# 2005 Audi  (2005 sales of 83066 vehicles)
# Slope 1.221565842044948 intercept -2433.5716035869395
# Initial fatality rate is 15.667909713181416 per year
# 2005 BMW  (2005 sales of 266200 vehicles)
# Slope 0.4198523887391696 intercept -809.2654792947542
# Initial fatality rate is 32.53856012728079 per year
# 2005 Cadillac  (2005 sales of 235002 vehicles)
# Slope 0.2190219157081776 intercept -350.62279820361965
# Initial fatality rate is 88.51614279127648 per year
# 2005 Chevrolet  (2005 sales of 2523539 vehicles)
# Slope -1.1963824006916868 intercept 2520.284713137557
# Initial fatality rate is 121.5379997507248 per year
# 2005 Ford  (2005 sales of 2455800 vehicles)
# Slope -0.5563060797247918 intercept 1205.764983735907
# Initial fatality rate is 90.37129388769927 per year
# 2005 GMC  (2005 sales of 513110 vehicles)
# Slope 2.344411873615136 intercept -4623.6072531176715
# Initial fatality rate is 76.93855348067609 per year
# 2005 Honda  (2005 sales of 1252862 vehicles)
# Slope -0.4037813844949815 intercept 932.0365972422087
# Initial fatality rate is 122.45492132977074 per year
# 2005 Hyundai  (2005 sales of 455012 vehicles)
# Slope -0.38460524118062983 intercept 851.9006092150595
# Initial fatality rate is 80.76710064789665 per year
# 2005 Jeep / Kaiser-Jeep / Willys- Jeep  (2005 sales of 476532 vehicles)
# Slope 0.25922584792754066 intercept -455.0648039927461
# Initial fatality rate is 64.68302110197294 per year
# 2005 KIA  (2005 sales of 275851 vehicles)
# Slope -3.2413065280128595 intercept 6622.8208877473235
# Initial fatality rate is 124.00129908154031 per year
# 2005 Lexus  (2005 sales of 302895 vehicles)
# Slope 1.8449414134000985 intercept -3679.517169122283
# Initial fatality rate is 19.590364744914496 per year
# 2005 Mercedes-Benz  (2005 sales of 224269 vehicles)
# Slope 0.681954155369808 intercept -1344.0070524555151
# Initial fatality rate is 23.31102906094975 per year
# 2005 Nissan/Datsun  (2005 sales of 940268 vehicles)
# Slope -0.19706521720095801 intercept 498.55935942179235
# Initial fatality rate is 103.44359893387156 per year
# 2005 Porsche  (2005 sales of 31933 vehicles)
# Slope -1.6481877351756498 intercept 3361.7535838466033
# Initial fatality rate is 57.13717481942558 per year
# 2005 Toyota  (2005 sales of 1800915 vehicles)
# Slope 0.6050845722052238 intercept -1144.2631041639133
# Initial fatality rate is 68.93146310756038 per year
# 2005 Volkswagen  (2005 sales of 224195 vehicles)
# Slope -0.24269838625273815 intercept 531.0831038635539
# Initial fatality rate is 44.47283942681389 per year
# 2005 Volvo  (2005 sales of 123598 vehicles)
# Slope -0.11898155595549242 intercept 318.3351529586746
# Initial fatality rate is 79.77713326791229 per year
