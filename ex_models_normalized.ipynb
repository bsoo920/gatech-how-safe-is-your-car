# %%
import csv as csv
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from c_online_linear_regression import getData, summarize_by_modelyear

dfMasterCrashAgg, dfSales = getData()

# %%
#     df_agg = aggregate(df_final, ['MOD_YEAR', 'Make_ID', 'Model_ID','ACC_YEAR'])
x = {}
x['Audi']  = {'Make_ID':32}
x['BMW']  = {'Make_ID':34}
x['Cadillac']  = {'Make_ID':19}
x['Chevrolet']  = {'Make_ID':20}
x['Ford']  = {'Make_ID':12}
x['GMC']  = {'Make_ID':23}
x['Honda']  = {'Make_ID':37}
x['Hyundai']  = {'Make_ID':55}
x['Jeep / Kaiser-Jeep / Willys- Jeep']  = {'Make_ID':2}
x['KIA']  = {'Make_ID':63}
x['Lexus']  = {'Make_ID':59}
x['Mercedes-Benz']  = {'Make_ID':42}
x['Nissan/Datsun']  = {'Make_ID':35}
x['Porsche']  = {'Make_ID':45}
x['Toyota']  = {'Make_ID':49}
x['Volkswagen']  = {'Make_ID':30}
x['Volvo']  = {'Make_ID':51}

x = {}
x['camry' ]        = {'Make_ID':49, 'Model_ID':40 }   
x['tacoma']        = {'Make_ID':49, 'Model_ID':472}   
x['FJ Cruiser']    = {'Make_ID':49, 'Model_ID':404}   
x['mustang']       = {'Make_ID':12, 'Model_ID':3  } 
x['ford_f_series'] = {'Make_ID':12, 'Model_ID':481}   
x['crown_vicoria'] = {'Make_ID':12, 'Model_ID':16 }  

# plt.rcParams['figure.figsize'] = [16, 8]

# modelYrStart=1999
# modelYrEnd  =2020

# # summarize_by_makeyear( dfMasterCrashAgg, modelYrStart, modelYrEnd, makes_dict=x)
# summarize_by_makeyear( dfMasterCrashAgg, modelYrStart, modelYrEnd, makes_dict=x, dfSales=dfSales
#                      , showLinearRegress=False)
    

print('ZOOMING IN...')
modelYrStart=2010
modelYrEnd  =2020

summarize_by_modelyear( dfMasterCrashAgg, modelYrStart, modelYrEnd, models_dict=x, dfSales=dfSales
                     , showLinearRegress=True)
# Out:
# ZOOMING IN...
# 2010 camry  (2010 sales of 327804 vehicles)
# Slope 1.1647758472081302 intercept -2295.163074165357
# Initial fatality rate is 46.03637872298441 per year
# 2011 camry  (2011 sales of 308510 vehicles)
# Slope 3.594991763933174 intercept -7158.512616359141
# Initial fatality rate is 71.01582091047112 per year
# 2012 camry  (2012 sales of 404886 vehicles)
# Slope 2.7991418160503496 intercept -5579.9519974622535
# Initial fatality rate is 51.921336431049895 per year
# 2013 camry  (2013 sales of 408484 vehicles)
# Slope 1.9234885227188812 intercept -3846.8896141412765
# Initial fatality rate is 25.092782091831396 per year
# 2014 camry  (2014 sales of 428606 vehicles)
# Slope 5.332903145812696 intercept -10696.137178267198
# Initial fatality rate is 44.32975739957146 per year
# 2015 camry  (2015 sales of 429355 vehicles)
# Slope 5.2570550177408375 intercept -10563.796968982666
# Initial fatality rate is 29.16889176512086 per year
# ...
