# %%
import csv as csv
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from c_online_linear_regression import getData, summarize_by_modelyear

dfMasterCrashAgg, dfSales = getData()

# %%
#     df_agg = aggregate(df_final, ['MOD_YEAR', 'Make_ID', 'Model_ID','ACC_YEAR'])


# Top 4% sold models (all years 2005-2021)
x = {}
x['Chevrolet Equinox']     ={'Make_ID':20 , 'Model_ID': 404}   
x['Chevrolet Impala']      ={'Make_ID':20 , 'Model_ID':   2}     
x['Chevrolet Malibu']      ={'Make_ID':20 , 'Model_ID':  37}    
x['Chevrolet Silverado']   ={'Make_ID':20 , 'Model_ID': 481}   
x['Ford Escape']           ={'Make_ID':12 , 'Model_ID': 402}   
x['Ford Explorer']         ={'Make_ID':12 , 'Model_ID': 425}   
x['Ford Focus']            ={'Make_ID':12 , 'Model_ID':  37}    
x['Ford F-Series']         ={'Make_ID':12 , 'Model_ID': 481}   
x['Ford Fusion']           ={'Make_ID':12 , 'Model_ID':  23}    
x['GMC Sierra']            ={'Make_ID':23 , 'Model_ID': 481}   
x['Honda Accord']          ={'Make_ID':37 , 'Model_ID':  32}    
x['Honda Civic']           ={'Make_ID':37 , 'Model_ID':  31}    
x['Honda CR-V']            ={'Make_ID':37 , 'Model_ID': 402}   
x['Hyundai Elantra']       ={'Make_ID':55 , 'Model_ID':  35}    
x['Hyundai Sonata']        ={'Make_ID':55 , 'Model_ID':  33}    
x['Jeep Grand Cherokee']   ={'Make_ID': 2 , 'Model_ID': 422}   
x['Jeep Wrangler']         ={'Make_ID': 2 , 'Model_ID': 403}   
x['Nissan Altima']         ={'Make_ID':35 , 'Model_ID':  47}    
x['Nissan Rogue']          ={'Make_ID':35 , 'Model_ID': 404}   
x['Nissan Sentra']         ={'Make_ID':35 , 'Model_ID':  43}    
x['Toyota Camry']          ={'Make_ID':49 , 'Model_ID':  40}    
x['Toyota Corolla/Matrix'] ={'Make_ID':49 , 'Model_ID':  32}    
x['Toyota Highlander']     ={'Make_ID':49 , 'Model_ID': 403}   
x['Toyota RAV4']           ={'Make_ID':49 , 'Model_ID': 402}   
x['Toyota Tacoma']         ={'Make_ID':49 , 'Model_ID': 472}   

plt.rcParams['figure.figsize'] = [16, 8]

modelYrStart=1999
modelYrEnd  =2020

summarize_by_modelyear( dfMasterCrashAgg, modelYrStart, modelYrEnd, models_dict=x, dfSales=dfSales
                     , showLinearRegress=False)
    

print('ZOOMING IN...')
plt.rcParams['figure.figsize'] = [8, 8]
modelYrStart=2018
modelYrEnd  =2020

summarize_by_modelyear( dfMasterCrashAgg, modelYrStart, modelYrEnd, models_dict=x, dfSales=dfSales
                     , showLinearRegress=False)
# Out:
# ZOOMING IN...
