# %%
import csv as csv
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from c_online_linear_regression import getData, summarize_by_makeyear

dfMasterCrashAgg, dfSales = getData()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-4d4471ce66f5> in <module>
#       6 from c_online_linear_regression import getData, summarize_by_makeyear
#       7
# ----> 8 dfMasterCrashAgg, dfSales = getData()
#
# ~/git/gatech-how-safe-is-your-car/c_online_linear_regression.py in getData(verbose)
#      10 def getData(verbose=False):
#      11     # get master aggregate
# ---> 12     dfMasterCrashAgg = pd.read_pickle('program_data/master_crash_aggregate.pkl')
#      13
#      14     # get sales data
#
# /Users/renyinzhang/opt/anaconda3/lib/python3.8/site-packages/pandas/io/pickle.py in read_pickle(filepath_or_buffer, compression)
#     185             #  "No module named 'pandas.core.sparse.series'"
#     186             #  "Can't get attribute '__nat_unpickle' on <module 'pandas._libs.tslib"
# --> 187             return pc.load(f, encoding=None)
#     188     except UnicodeDecodeError:
#     189         # e.g. can occur for files written in py27; see GH#28645 and GH#31988
#
# /Users/renyinzhang/opt/anaconda3/lib/python3.8/site-packages/pandas/compat/pickle_compat.py in load(fh, encoding, is_verbose)
#     239         up.is_verbose = is_verbose
#     240
# --> 241         return up.load()
#     242     except (ValueError, TypeError):
#     243         raise
#
# /Users/renyinzhang/opt/anaconda3/lib/python3.8/pickle.py in load(self)
#    1208                     raise EOFError
#    1209                 assert isinstance(key, bytes_types)
# -> 1210                 dispatch[key[0]](self)
#    1211         except _Stop as stopinst:
#    1212             return stopinst.value
#
# /Users/renyinzhang/opt/anaconda3/lib/python3.8/pickle.py in load_stack_global(self)
#    1533         if type(name) is not str or type(module) is not str:
#    1534             raise UnpicklingError("STACK_GLOBAL requires str")
# -> 1535         self.append(self.find_class(module, name))
#    1536     dispatch[STACK_GLOBAL[0]] = load_stack_global
#    1537
#
# /Users/renyinzhang/opt/anaconda3/lib/python3.8/site-packages/pandas/compat/pickle_compat.py in find_class(self, module, name)
#     178         key = (module, name)
#     179         module, name = _class_locations_map.get(key, key)
# --> 180         return super().find_class(module, name)
#     181
#     182
#
# /Users/renyinzhang/opt/anaconda3/lib/python3.8/pickle.py in find_class(self, module, name)
#    1577         __import__(module, level=0)
#    1578         if self.proto >= 4:
# -> 1579             return _getattribute(sys.modules[module], name)[0]
#    1580         else:
#    1581             return getattr(sys.modules[module], name)
#
# /Users/renyinzhang/opt/anaconda3/lib/python3.8/pickle.py in _getattribute(obj, name)
#     329             obj = getattr(obj, subpath)
#     330         except AttributeError:
# --> 331             raise AttributeError("Can't get attribute {!r} on {!r}"
#     332                                  .format(name, obj)) from None
#     333     return obj, parent
#
# AttributeError: Can't get attribute '_unpickle_block' on <module 'pandas._libs.internals' from '/Users/renyinzhang/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/internals.cpython-38-darwin.so'>

# %%
#     df_agg = aggregate(df_final, ['MOD_YEAR', 'Make_ID', 'Model_ID','ACC_YEAR'])
x = {}
# x['Alfa Romeo']  = {'Make_ID':31}
# x['AM General']  = {'Make_ID':3}
# x['American Motors']  = {'Make_ID':1}
x['Audi']  = {'Make_ID':32}
# x['Austin/Austin Healey']  = {'Make_ID':33}
# x['Bluebird']  = {'Make_ID':90}
x['BMW']  = {'Make_ID':34}
# x['Brockway']  = {'Make_ID':80}
# x['BSA']  = {'Make_ID':70}
# x['Buick / Opel']  = {'Make_ID':18}
x['Cadillac']  = {'Make_ID':19}
x['Chevrolet']  = {'Make_ID':20}
# x['Chrysler']  = {'Make_ID':6}
# x['Coda']  = {'Make_ID':26}
# x['Daewoo']  = {'Make_ID':64}
# x['Daihatsu']  = {'Make_ID':60}
# x['Diamond Reo/Reo']  = {'Make_ID':81}
# x['Dodge']  = {'Make_ID':7}
# x['Ducati']  = {'Make_ID':71}
# x['Eagle']  = {'Make_ID':10}
# x['Eagle Coach']  = {'Make_ID':91}
# x['Fiat']  = {'Make_ID':36}
x['Ford']  = {'Make_ID':12}
# x['Freightliner']  = {'Make_ID':82}
# x['FWD']  = {'Make_ID':83}
# x['Gillig']  = {'Make_ID':92}
x['GMC']  = {'Make_ID':23}
# x['Grumman']  = {'Make_ID':25}
# x['Harley-Davidson']  = {'Make_ID':72}
x['Honda']  = {'Make_ID':37}
x['Hyundai']  = {'Make_ID':55}
# x['Imperial']  = {'Make_ID':8}
# x['Infiniti']  = {'Make_ID':58}
# x['International Harvester/Navistar']  = {'Make_ID':84}
# x['Isuzu']  = {'Make_ID':38}
# x['Iveco/Magirus']  = {'Make_ID':88}
# x['Jaguar']  = {'Make_ID':39}
x['Jeep / Kaiser-Jeep / Willys- Jeep']  = {'Make_ID':2}
# x['Kawasaki']  = {'Make_ID':73}
# x['Kenworth']  = {'Make_ID':85}
x['KIA']  = {'Make_ID':63}
# x['Lancia']  = {'Make_ID':40}
# x['Land Rover']  = {'Make_ID':62}
x['Lexus']  = {'Make_ID':59}
# x['Lincoln']  = {'Make_ID':13}
# x['Mack']  = {'Make_ID':86}
# x['Mazda']  = {'Make_ID':41}
# x['MCI']  = {'Make_ID':93}
x['Mercedes-Benz']  = {'Make_ID':42}
# x['Mercury']  = {'Make_ID':14}
# x['Merkur']  = {'Make_ID':56}
# x['MG']  = {'Make_ID':43}
# x['Mitsubishi']  = {'Make_ID':52}
# x['Moto-Guzzi']  = {'Make_ID':74}
x['Nissan/Datsun']  = {'Make_ID':35}
# x['Norton']  = {'Make_ID':75}
# x['Not Reported']  = {'Make_ID':97}
# x['Oldsmobile']  = {'Make_ID':21}
# x['Other Domestic Manufacturers']  = {'Make_ID':29}
# x['Other Import']  = {'Make_ID':69}
# x['Other Make']  = {'Make_ID':98}
# x['Peterbilt']  = {'Make_ID':87}
# x['Peugeot']  = {'Make_ID':44}
# x['Plymouth']  = {'Make_ID':9}
# x['Pontiac']  = {'Make_ID':22}
x['Porsche']  = {'Make_ID':45}
# x['Renault']  = {'Make_ID':46}
# x['Saab']  = {'Make_ID':47}
# x['Saturn']  = {'Make_ID':24}
# x['Scion']  = {'Make_ID':67}
# x['Smart']  = {'Make_ID':65}
# x['Sterling']  = {'Make_ID':61}
# x['Subaru']  = {'Make_ID':48}
# x['Suzuki']  = {'Make_ID':53}
# x['Thomas Built']  = {'Make_ID':94}
x['Toyota']  = {'Make_ID':49}
# x['Triumph']  = {'Make_ID':50}
# x['Unknown Make']  = {'Make_ID':99}
# x['Victory']  = {'Make_ID':77}
x['Volkswagen']  = {'Make_ID':30}
x['Volvo']  = {'Make_ID':51}
# x['White/Autocar White/GMC']  = {'Make_ID':89}
# x['Yamaha']  = {'Make_ID':76}
# x['Yugo']  = {'Make_ID':57}

plt.rcParams['figure.figsize'] = [16, 8]


modelYrStart=1999
modelYrEnd  =2020

# summarize_by_makeyear( dfMasterCrashAgg, modelYrStart, modelYrEnd, makes_dict=x)
summarize_by_makeyear( dfMasterCrashAgg, modelYrStart, modelYrEnd, makes_dict=x
                     , showLinearRegress=False)

print('ZOOMING IN...')

modelYrStart=2017
modelYrEnd  =2020

# summarize_by_makeyear( dfMasterCrashAgg, modelYrStart, modelYrEnd, makes_dict=x)
summarize_by_makeyear( dfMasterCrashAgg, modelYrStart, modelYrEnd, makes_dict=x
                     , showLinearRegress=False)
# Out:
# filtering by MOD_YEAR>=1999 , aggregating by ['MOD_YEAR', 'Make_ID', 'ACC_YEAR']
# ZOOMING IN...
# filtering by MOD_YEAR>=1999 , aggregating by ['MOD_YEAR', 'Make_ID', 'ACC_YEAR']
